# %%
from sympy import *
import numpy as np
import matplotlib.pyplot as pt
from mpl_toolkits.mplot3d import axes3d
import math

# %% [markdown]
# # Question 2

# %%
#question2
def f(x):
    return 8*(x[0]**2)-6*x[0]*x[1]+8*(x[1]**2)-x[0]+x[1]
def df(x):
    return np.array([16*x[0] - 6*x[1] - 1, -6*x[0] + 16*x[1] + 1])

# %%
fig = pt.figure()
ax = fig.gca(projection="3d")

xmesh, ymesh = np.mgrid[-2:2:50j,-2:2:50j]
fmesh = f(np.array([xmesh, ymesh]))
ax.plot_surface(xmesh, ymesh, fmesh)

# %%
import numpy as np
from sympy import symbols, solve

def get_lambda(l,x):
    sol = solve(diff(f(x)), l)
    sol = np.array([float(re(i)) for i in sol])
    return sol[-1]

def norm(x):
    return (math.sqrt(x[0]**2+x[1]**2))

guesses = [np.array( [100,0])]
x = [100,0]
x_new = x
for i in range(6):
    print('Iteration:',i-1, 'x and func values:',x,f(x))
    if f(x_new)<=f(x):
        if i==1:
            s_new = -df(x)
        if i>1:
            s_new = -df(x_new) + ((norm(df(x_new))**2)/(norm(df(x))**2))*s
        x = x_new
        l = symbols('l')
        lamb = [-l,l]
        x_symb = x + l*s_new
        l_val = get_lambda(l,x_symb)
        x_new = x + l_val*s_new
        s = s_new
        guesses.append(x)
# Out:
# Iteration: -1 x and func values: [100, 0] 79900
# Iteration: 0 x and func values: [100, 0] 79900
# Iteration: 1 x and func values: [ 84.75579104 -25.20958956] 75262.52700582924
# Iteration: 2 x and func values: [3.51011284 5.22578332] 208.69476366789303
# Iteration: 3 x and func values: [ 1.28124244 -0.10825874] 12.669150257734184
# Iteration: 4 x and func values: [ 0.06330873 -0.00536625] -0.03434226303662121

# %%
del guesses[0]

# %%
x = np.linspace(-150, 150, 1000)
y = np.linspace(-150, 150, 1000)
xx, yy = np.meshgrid(x, y)
fmesh = f(np.array([xx, yy]))
pt.figure(figsize=(10, 8))
pt.pcolormesh(xx, yy, fmesh)
pt.colorbar()
it_array = np.array(guesses)
pt.plot(it_array.T[0], it_array.T[1], "x-", color = 'white')
pt.text(guesses[0][0]-3, guesses[0][1]+5, 'start', color='w', fontsize=12, fontweight='bold')
pt.text(guesses[-1][0]-3, guesses[-1][1]+5, 'end', color='w', fontsize=12, fontweight='bold')
pt.title('Conjugate Descent method for Question 2')
pt.grid()
pt.show()

# %% [markdown]
# # Question 3

# %%
#question3
def f(x):
    return 100*(x[1]-x[0]**2)**2 + (1-x[0])**2

def df(x):
    return np.array([-400*x[0]*(-x[0]**2 + x[1]) + 2*x[0] - 2, -200*x[0]**2 + 200*x[1]])

# %%
fig = pt.figure()
ax = fig.gca(projection="3d")

xmesh, ymesh = np.mgrid[-2:2:50j,-2:2:50j]
fmesh = f(np.array([xmesh, ymesh]))
ax.plot_surface(xmesh, ymesh, fmesh)

# %%
import numpy as np
from sympy import symbols, solve

def get_lambda(l,x):
    sol = solve(diff(f(x)), l)
    sol = np.array([float(re(i)) for i in sol])
    return sol[-1]

def norm(x):
    return (math.sqrt(x[0]**2+x[1]**2))

guesses = [np.array( [-1.2,1.0])]
x = [-1.2,1.0]
x_new = x
for i in range(7):
    print('Iteration:',i-1, 'x and func values:',x,f(x))
    if f(x_new)<=f(x):
        if i==1:
            s_new = -df(x)
        if i>1:
            s_new = -df(x_new) + ((norm(df(x_new))**2)/(norm(df(x))**2))*s
        x = x_new
        l = symbols('l')
        lamb = [-l,l]
        x_symb = x + l*s_new
        l_val = get_lambda(l,x_symb)
        x_new = x + l_val*s_new
        s = s_new
        guesses.append(x)
# Out:
# Iteration: -1 x and func values: [-1.2, 1.0] 24.199999999999996
# Iteration: 0 x and func values: [-1.2, 1.0] 24.199999999999996
# Iteration: 1 x and func values: [1.43089424 2.04920779] 0.18597591022804066
# Iteration: 2 x and func values: [1.43089152 2.04920668] 0.18597590577829584
# Iteration: 3 x and func values: [1.43089206 2.04920691] 0.1859759055991185
# Iteration: 4 x and func values: [1.43089261 2.04920713] 0.1859759054204474
# Iteration: 5 x and func values: [1.43089315 2.04920734] 0.18597590524228066

# %%
del guesses[0]

# %%
x = np.linspace(-5, 5, 1000)
y = np.linspace(-5, 5, 1000)
xx, yy = np.meshgrid(x, y)
fmesh = f(np.array([xx, yy]))
pt.figure(figsize=(10, 8))
pt.pcolormesh(xx, yy, fmesh)
pt.colorbar()
it_array = np.array(guesses)
pt.plot(it_array.T[0], it_array.T[1], "x-", color = 'white')
pt.text(guesses[0][0], guesses[0][1], 'start', color='w', fontsize=12, fontweight='bold')
pt.text(guesses[-1][0], guesses[-1][1], 'end', color='w', fontsize=12, fontweight='bold')
pt.title('Conjugate Descent method for Question 3')
pt.grid()
pt.show()
