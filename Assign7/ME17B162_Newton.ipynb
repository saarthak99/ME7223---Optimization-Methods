# %%
from sympy import *
import numpy as np
import matplotlib.pyplot as pt
from mpl_toolkits.mplot3d import axes3d
import math

# %% [markdown]
# # Question 2

# %%
#question2
def f(x):
    return 8*(x[0]**2)-6*x[0]*x[1]+8*(x[1]**2)-x[0]+x[1]
def df(x):
    return np.array([16*x[0] - 6*x[1] - 1, -6*x[0] + 16*x[1] + 1])

def hes(x):
    return np.array([[16,-6],[-6,16]])

# %%
fig = pt.figure()
ax = fig.gca(projection="3d")

xmesh, ymesh = np.mgrid[-2:2:50j,-2:2:50j]
fmesh = f(np.array([xmesh, ymesh]))
ax.plot_surface(xmesh, ymesh, fmesh)

# %%
import numpy as np
from sympy import symbols, solve

def norm(x):
    return (math.sqrt(x[0]**2+x[1]**2))

guesses = [np.array( [100,0])]
x = [100,0]
x_new = x
invj = np.linalg.inv(hes(x)) 
for i in range(6):
    print('Iteration:',i, 'x and func values:',x,f(x))
    if (f(x_new))<=(f(x)):
        invj = np.linalg.inv(hes(x)) 
        x_new = x -np.dot(invj,df(x))
        x = x_new
        guesses.append(x)
# Out:
# Iteration: 0 x and func values: [100, 0] 79900
# Iteration: 1 x and func values: [ 0.04545455 -0.04545455] -0.045454545454545456
# Iteration: 2 x and func values: [ 0.04545455 -0.04545455] -0.045454545454545456
# Iteration: 3 x and func values: [ 0.04545455 -0.04545455] -0.045454545454545456
# Iteration: 4 x and func values: [ 0.04545455 -0.04545455] -0.045454545454545456
# Iteration: 5 x and func values: [ 0.04545455 -0.04545455] -0.045454545454545456

# %%
x = np.linspace(-150, 150, 1000)
y = np.linspace(-150, 150, 1000)
xx, yy = np.meshgrid(x, y)
fmesh = f(np.array([xx, yy]))
pt.figure(figsize=(10, 8))
pt.pcolormesh(xx, yy, fmesh)
pt.colorbar()
it_array = np.array(guesses)
pt.plot(it_array.T[0], it_array.T[1], "x-", color = 'white')
pt.text(guesses[0][0]-3, guesses[0][1]+5, 'start', color='w', fontsize=12, fontweight='bold')
pt.text(guesses[-1][0]-3, guesses[-1][1]+5, 'end', color='w', fontsize=12, fontweight='bold')
pt.title('Newton method for Question 2')
pt.grid()
pt.show()

# %% [markdown]
# # Question 3

# %%
#question3
def f(x):
    return 100*(x[1]-x[0]**2)**2 + (1-x[0])**2

def df(x):
    return np.array([-400*x[0]*(-x[0]**2 + x[1]) + 2*x[0] - 2, -200*x[0]**2 + 200*x[1]])

def hes(x):
    return np.array([[1200*x[0]**2 - 400*x[1] + 2, -400*x[0]],[-400*x[0], 200]])

# %%
fig = pt.figure()
ax = fig.gca(projection="3d")

xmesh, ymesh = np.mgrid[-2:2:50j,-2:2:50j]
fmesh = f(np.array([xmesh, ymesh]))
ax.plot_surface(xmesh, ymesh, fmesh)

# %%
import numpy as np
from sympy import symbols, solve

def norm(x):
    return (math.sqrt(x[0]**2+x[1]**2))

guesses = [np.array( [-1.2,1.0])]
x = [-1.2,1.0]
x_new = x
invj = np.linalg.inv(hes(x)) 
for i in range(6):
    print('Iteration:',i, 'x and func values:',x,f(x))
    if (f(x_new))<=(f(x)):
        invj = np.linalg.inv(hes(x)) 
        x_new = x -np.dot(invj,df(x))
        x = x_new
        guesses.append(x)
# Out:
# Iteration: 0 x and func values: [-1.2, 1.0] 24.199999999999996
# Iteration: 1 x and func values: [-1.1752809   1.38067416] 4.731884325266611
# Iteration: 2 x and func values: [ 0.76311487 -3.17503385] 1411.8451793094825
# Iteration: 3 x and func values: [0.76342968 0.58282478] 0.05596551683394537
# Iteration: 4 x and func values: [0.99999531 0.94402732] 0.31318907611673635
# Iteration: 5 x and func values: [0.9999957  0.99999139] 1.852739700580546e-11

# %%
x = np.linspace(-5, 5, 1000)
y = np.linspace(-5, 5, 1000)
xx, yy = np.meshgrid(x, y)
fmesh = f(np.array([xx, yy]))
pt.figure(figsize=(10, 8))
pt.pcolormesh(xx, yy, fmesh)
pt.colorbar()
it_array = np.array(guesses)
pt.plot(it_array.T[0], it_array.T[1], "x-", color = 'white')
pt.text(guesses[0][0], guesses[0][1], 'start', color='w', fontsize=12, fontweight='bold')
pt.text(guesses[-1][0], guesses[-1][1], 'end', color='w', fontsize=12, fontweight='bold')
pt.title('Newton method for Question 3')
pt.grid()
pt.show()
